# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelEncoder

#dataset
df=pd.DataFrame({
    'Temp':[38.5,36.7,39.2,37.0,39.5,36.8,38.9,37.2,39.0,36.5],
    'headache':['yes','no','yes','no','yes','no','yes','no','yes','no'],
    'Stomachache':['no','no','yes','yes','yes','no','no','yes','yes','no'],
    'Fever':['yes','no','yes','no','yes','no','yes','no','yes','no']
})

#let us Encode Categorical Features 
le=LabelEncoder()
for col in ['headache','Stomachache','Fever']:
    df[col]=le.fit_transform(df[col])

#let us train CART model
x=df[['Temp','headache','Stomachache']]
y=df['Fever']

model=DecisionTreeClassifier(criterion='gini',max_depth=2)
model.fit(x,y)

# let us visual Tree 
plt.figure(figsize=(8,6))
plot_tree(model,feature_names=x.columns,class_names=['yes','no'],filled=True)
plt.show()

# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("banana_quality_dataset.csv")

# %%
#drop 
df.drop(["sample_id","harvest_date"],axis=1,inplace=True)

# %%
y=df['quality_category']

# %%
x =df.drop(['quality_category'],axis=1)

# %%
#apply columntransformer 
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder,StandardScaler
ct=ColumnTransformer(transformers=[("oe",OrdinalEncoder(),[0,1,4]),
                                   ("sc",StandardScaler(),[2,3,5,6,7,8,9,10,11,12])])

# %%
x_transformed=ct.fit_transform(x)

# %%
x_transformed=pd.DataFrame(x_transformed,columns=x.columns)
x_transformed
# Out:
#      variety  region  quality_score  ripeness_index  ripeness_category  \
# 0        5.0     1.0            3.0       -1.082350          -1.102626
# 1        6.0     4.0            2.0       -0.083531           0.118602
# 2        1.0     3.0            1.0        2.043584           1.254230
# 3        5.0     3.0            2.0       -0.471961           0.769163
# 4        7.0     3.0            2.0       -0.213007           1.025963
# ..       ...     ...            ...             ...                ...
# 995      1.0     3.0            2.0        1.914108           0.512362
# 996      2.0     7.0            1.0       -0.157518           1.539564
# 997      6.0     3.0            0.0       -1.452283          -1.502094
# 998      3.0     4.0            0.0       -0.823397          -1.542040
# 999      7.0     3.0            3.0        0.415879          -0.771639
#
#      sugar_content_brix  firmness_kgf  length_cm  weight_g  tree_age_years  \
# 0             -0.829400      0.638798   0.271721 -0.362627        0.541038
# 1             -0.878570      1.073376   1.086240 -0.086672       -1.108701
# 2              1.388129     -0.835662   0.927522  1.231846        1.308358
# 3             -0.868736      0.468071  -1.186389 -0.548225        0.406757
# 4             -0.794982      0.281824  -1.203830  1.284148       -1.166250
# ..                  ...           ...        ...       ...             ...
# 995            1.250456     -0.168275   1.407163  0.643306        0.291659
# 996           -1.188335     -0.548530  -1.306735  0.016506        0.598587
# 997           -0.662225     -0.331241  -0.579424  0.922720        1.442639
# 998           -0.731062      0.134378   1.121123 -0.045564       -0.514028
# 999            1.270123     -1.146075   0.360673 -1.207789        0.445123
#
#      altitude_m  rainfall_mm  soil_nitrogen_ppm
# 0     -1.557632     0.828641           1.478299
# 1     -1.037919     0.711835           0.100944
# 2      1.225172    -1.385170           0.808285
# 3      0.998792     1.545781          -0.216332
# 4     -0.462490     0.290520           0.472345
# ..          ...          ...                ...
# 995   -0.734754     0.100866           1.280467
# 996   -0.958090    -1.138442           1.420442
# 997   -0.094945     1.741284           1.595878
# 998    1.496265    -1.342099          -0.352575
# 999   -1.327039     1.579103          -0.990861
#
# [1000 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
#apply columntransformer 
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder,StandardScaler
ct=ColumnTransformer(transformers=[("oe",OrdinalEncoder(),[0,1,4]),
                                   ("sc",StandardScaler(),[2,3,5,6,7,8,9,10,11,12])])

# %%
x_transformed=ct.fit_transform(x)

# %%
model=DecisionTreeClassifier(criterion='gini',max_depth=2)
model.fit(x_transformed,y_train)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
ct=ct=ColumnTransformer(transformers=[("oe",OrdinalEncoder(),[0,3,]),
                                   ("sc",StandardScaler(),[1,2,4,5,6,7])])

# %%
x_train_transform=ct.fit_transform(x_train)
x_train_transform=pd.DataFrame(x_train_transform)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_53692\3122675380.py in ?()
# ----> 1 x_train_transform=ct.fit_transform(x_train)
#       2 x_train_transform=pd.DataFrame(x_train_transform)
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, X, y, **params)
#     997             routed_params = process_routing(self, "fit_transform", **params)
#     998         else:
#     999             routed_params = self._get_empty_routing()
#    1000
# -> 1001         result = self._call_func_on_transformers(
#    1002             X,
#    1003             y,
#    1004             _fit_transform_one,
#
# ~\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, X, y, func, column_as_labels, routed_params)
#     912         except ValueError as e:
#     913             if "Expected 2D array, got 1D array instead" in str(e):
#     914                 raise ValueError(_ERR_MSG_1DCOLUMN) from e
#     915             else:
# --> 916                 raise
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py in ?(self, iterable)
#      73         iterable_with_config = (
#      74             (_with_config(delayed_func, config), args, kwargs)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#
# ~\anaconda3\Lib\site-packages\joblib\parallel.py in ?(self, iterable)
#    1914             # If n_jobs==1, run the computation sequentially and return
#    1915             # immediately to avoid overheads.
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#    1921         # call is interrupted early and that the same instance is immediately
#
# ~\anaconda3\Lib\site-packages\joblib\parallel.py in ?(self, iterable)
#    1857         finally:
#    1858             self.print_progress()
#    1859             self._running = False
#    1860             self._iterating = False
# -> 1861             self._original_iterator = None
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py in ?(self, *args, **kwargs)
#     135                 UserWarning,
#     136             )
#     137             config = {}
#     138         with config_context(**config):
# --> 139             return self.function(*args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\pipeline.py in ?(transformer, X, y, weight, message_clsname, message, params)
#    1547     """
#    1548     params = params or {}
#    1549     with _print_elapsed_time(message_clsname, message):
#    1550         if hasattr(transformer, "fit_transform"):
# -> 1551             res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1552         else:
#    1553             res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1554                 X, **params.get("transform", {})
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     914                 )
#     915
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# --> 918             return self.fit(X, **fit_params).transform(X)
#     919         else:
#     920             # fit method of arity 2 (supervised transformation)
#     921             return self.fit(X, y, **fit_params).transform(X)
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     890             Fitted scaler.
#     891         """
#     892         # Reset internal state before fitting
#     893         self._reset()
# --> 894         return self.partial_fit(X, y, sample_weight)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     926         self : object
#     927             Fitted scaler.
#     928         """
#     929         first_call = not hasattr(self, "n_samples_seen_")
# --> 930         X = validate_data(
#     931             self,
#     932             X,
#     933             accept_sparse=("csr", "csc"),
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2940             out = y
#    2941         else:
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#    2947     else:
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Costa Rica'
