# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

corpus=["i love nlp",
        " i love machine learning"
       ]

vectorizer=TfidfVectorizer()
X=vectorizer.fit_transform(corpus)

print("Vocabulary:", vectorizer.get_feature_names_out())
print("TF-IDF Matrix:\n",X.toarray())
# Out:
# Vocabulary: ['learning' 'love' 'machine' 'nlp']
# TF-IDF Matrix:
#  [[0.         0.57973867 0.         0.81480247]
#  [0.6316672  0.44943642 0.6316672  0.        ]]

# %%
df=pd.read_csv("amazon_reviews.csv")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer=TfidfVectorizer()
X=vectorizer.fit_transform(df["cleaned_review"])
print("Vocabulary:",vectorizer.get_feature_names_out())
print("TF-IDF Matrix:\n",X.toarray())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 from sklearn.feature_extraction.text import TfidfVectorizer
#       3 vectorizer=TfidfVectorizer()
# ----> 4 X=vectorizer.fit_transform(df["cleaned_review"])
#       5 print("Vocabulary:",vectorizer.get_feature_names_out())
#       6 print("TF-IDF Matrix:\n",X.toarray())
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:2104, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2097 self._check_params()
#    2098 self._tfidf = TfidfTransformer(
#    2099     norm=self.norm,
#    2100     use_idf=self.use_idf,
#    2101     smooth_idf=self.smooth_idf,
#    2102     sublinear_tf=self.sublinear_tf,
#    2103 )
# -> 2104 X = super().fit_transform(raw_documents)
#    2105 self._tfidf.fit(X)
#    2106 # X is already a transformed view of raw_documents so
#    2107 # we set copy to False
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1376, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1368             warnings.warn(
#    1369                 "Upper case characters found in"
#    1370                 " vocabulary while 'lowercase'"
#    1371                 " is True. These entries will not"
#    1372                 " be matched with any documents"
#    1373             )
#    1374             break
# -> 1376 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1378 if self.binary:
#    1379     X.data.fill(1)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1263, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1261 for doc in raw_documents:
#    1262     feature_counter = {}
# -> 1263     for feature in analyze(doc):
#    1264         try:
#    1265             feature_idx = vocabulary[feature]
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:99, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#      77 """Chain together an optional series of text processing steps to go from
#      78 a single document to ngrams, with or without tokenizing or preprocessing.
#      79
#    (...)
#      95     A sequence of tokens, possibly with pairs, triples, etc.
#      96 """
#      98 if decoder is not None:
# ---> 99     doc = decoder(doc)
#     100 if analyzer is not None:
#     101     doc = analyzer(doc)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:232, in _VectorizerMixin.decode(self, doc)
#     229     doc = doc.decode(self.encoding, self.decode_error)
#     231 if doc is np.nan:
# --> 232     raise ValueError(
#     233         "np.nan is an invalid document, expected byte or unicode string."
#     234     )
#     236 return doc
#
# ValueError: np.nan is an invalid document, expected byte or unicode string.

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.20.0)
# Requirement already satisfied: nltk>=3.9 in C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages (from textblob) (3.9.4)
# Requirement already satisfied: click in C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9->textblob) (8.3.2)
# Requirement already satisfied: joblib in C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9->textblob) (2026.4.4)
# Requirement already satisfied: tqdm in C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9->textblob) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\admin\anaconda3\python.exe

# %%
import sys
# !{sys.executable} -m pip install textblob
# Out:
# Collecting textblob
#   Using cached textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: nltk>=3.9 in c:\users\admin\anaconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\admin\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in c:\users\admin\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\admin\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Using cached textblob-0.20.0-py3-none-any.whl (624 kB)
# Installing collected packages: textblob
# Successfully installed textblob-0.20.0

# %%
from textblob import TextBlob

# %%
text="i am  a very good student"

# %%
analysis = TextBlob(text)
analysis.sentiment.polarity
# Out:
# 0.9099999999999999

# %%
text="sun rises in the east"
x=TextBlob(text)
x.sentiment.polarity
# Out:
# 0.0
